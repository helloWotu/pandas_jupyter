# %%
import pandas as pd

df = pd.read_csv('new.csv')
df.set_index('ymd', inplace=True)
df.head()
# Out:
#             high  low tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2021-01-01     1  -11      晴       东北风     1级   54       良         2
# 2021-01-02     0   -9   晴~多云       东北风     1级   78       良         2
# 2021-01-03    -1   -8     多云       东北风     1级   31       优         1
# 2021-01-04     0  -11   多云~晴       西北风     3级   36       优         1
# 2021-01-05    -2  -11      晴       西北风     2级   32       优         1

# %% [markdown]
# ### 函数查询
#
# **一般用于复杂数据查询或者需要计算的数据查询

# %%
# 查询所有9月份，天气质量好的数据

# 1.先定义一个函数
def query_my_data(df):
   result= df['high'] >  df['high'].mean
#    return df.index.str.startswith('2021-09') & df['aqiLevel'] == 1

df.loc[query_my_data, : ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 8
#       5    result= df['high'] >  df['high'].mean
#       6 #    return df.index.str.startswith('2021-09') & df['aqiLevel'] == 1
# ----> 8 df.loc[query_my_data, : ]
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1094, in _LocationIndexer.__getitem__(self, key)
#    1092 if type(key) is tuple:
#    1093     key = tuple(list(x) if is_iterator(x) else x for x in key)
# -> 1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1094, in <genexpr>(.0)
#    1092 if type(key) is tuple:
#    1093     key = tuple(list(x) if is_iterator(x) else x for x in key)
# ...

# %%
# 查询所有9月份，天气质量好的数据

result = df.index.str.startswith('2021-09') & (df['aqiLevel'] == 1)

df.loc[result, :]
# Out:
#             high  low  tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2021-09-01    29   18       晴       西南风     2级   41       优         1
# 2021-09-04    24   19      多云       东南风     1级   40       优         1
# 2021-09-05    24   22   多云~中雨       东南风     1级   30       优         1
# 2021-09-06    23   14    多云~晴        北风     2级   19       优         1
# 2021-09-07    27   17       晴       西南风     2级   32       优         1
# 2021-09-08    28   19    多云~阴       东南风     1级   44       优         1
# 2021-09-09    27   18    多云~阴       东南风     1级   49       优         1
# 2021-09-13    29   20  多云~雷阵雨       东北风     2级   39       优         1
# 2021-09-14    25   17      多云       东南风     1级   42       优         1
# 2021-09-15    25   19   多云~小雨        南风     1级   46       优         1
# 2021-09-16    24   17    小雨~雾       东北风     1级   36       优         1
# 2021-09-17    27   17    多云~晴       东南风     1级   31       优         1
# ...
